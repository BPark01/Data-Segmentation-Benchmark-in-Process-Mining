# %% [markdown]
# # Trace Clustering

# %%
import segmentation as sg
import pm4py as pm
import pandas as pd
import numpy as np
import os
from sklearn.feature_extraction.text import CountVectorizer
from pm4py.objects.log.util import dataframe_utils
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import TruncatedSVD
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
path = os.path.join(os.getcwd(),'data', 'mimicel.csv')
df = pd.read_csv(path)

# %% [markdown]
# ## Understanding Data

# %%
df.info(verbose=True)
# subject_id as CaseId (consistency wit sepsis benchmark)
# timestamps and activities
# gender or race? (Instead of Age)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7568824 entries, 0 to 7568823
# Data columns (total 31 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   stay_id            int64
#  1   subject_id         int64
#  2   hadm_id            float64
#  3   timestamps         object
#  4   activity           object
#  5   gender             object
#  6   race               object
#  7   arrival_transport  object
#  8   disposition        object
#  9   seq_num            float64
#  10  icd_code           object
#  11  icd_version        float64
#  12  icd_title          object
#  13  temperature        float64
#  14  heartrate          float64
#  15  resprate           float64
#  16  o2sat              float64
#  17  sbp                float64
#  18  dbp                float64
#  19  pain               object
#  20  acuity             float64
#  21  chiefcomplaint     object
#  22  rhythm             object
#  23  name               object
#  24  gsn                float64
#  25  ndc                float64
#  26  etc_rn             float64
#  27  etccode            float64
#  28  etcdescription     object
#  29  med_rn             float64
#  30  gsn_rn             float64
# dtypes: float64(16), int64(2), object(13)
# memory usage: 1.7+ GB

# %%
df = df.rename(columns={
    'subject_id': 'case:concept:name',      
    'activity': 'concept:name',               
    'timestamps': 'time:timestamp'           
})

# %%
group = df.groupby("case:concept:name")

# %%
df.isnull().sum()
# Out:
# stay_id                    0
# case:concept:name          0
# hadm_id              3015236
# time:timestamp             0
# concept:name               0
# gender               7143796
# race                 7143796
# arrival_transport    7143796
# disposition          6668747
# seq_num              6669845
# icd_code             6669845
# icd_version          6669845
# icd_title            6669845
# temperature          6259715
# heartrate            5801023
# resprate             5822404
# o2sat                5864053
# sbp                  5812828
# dbp                  5813628
# pain                 6131688
# acuity               7150772
# chiefcomplaint       7143817
# rhythm               7515079
# name                 3173867
# gsn                  3206271
# ndc                  4615706
# etc_rn               4615706
# etccode              4627281
# etcdescription       4627281
# med_rn               6126985
# gsn_rn               6126985
# dtype: int64

# %% [markdown]
# ## Preprocessing the Data

# %%
activities = df['concept:name'].unique() # extract activities

# mapping activities
mapping = {act: chr(97 + i) for i, act in enumerate(activities)} 
df['activity_mapped'] = df['concept:name'].map(mapping)

trace_ordered_df = df.sort_values(by=['case:concept:name', 'time:timestamp']) # order by case ids
trace_mapped_df = trace_ordered_df.groupby('case:concept:name')["activity_mapped"].apply(list).reset_index() # group by case ids

# %%
trace_mapped_df.head()
# Out:
#    case:concept:name                                    activity_mapped
# 0           10000032  [b, c, d, d, d, d, d, d, d, d, d, d, a, f, f, ...
# 1           10000084  [b, c, a, d, d, d, d, d, d, a, e, a, f, f, b, ...
# 2           10000108  [b, c, a, f, b, c, a, e, e, f, b, c, d, a, e, ...
# 3           10000115               [b, c, a, a, f, f, f, b, a, c, f, f]
# 4           10000117  [b, c, a, d, a, f, b, c, a, f, f, f, b, c, a, ...

# %% [markdown]
# ## Feature Generation and Transformation

# %%
trace_mapped_df['activity_str'] = trace_mapped_df['activity_mapped'].apply(lambda x: ' '.join(x))

vectorizer = CountVectorizer(
    ngram_range=(3, 4),
    stop_words=None,                     
    token_pattern=r'(?u)\b\w+\b'         
)

X = vectorizer.fit_transform(trace_mapped_df['activity_str'])

# %% [markdown]
# ## Feature Selection

# %%
df_counts = np.asarray(X.sum(axis=0)).flatten()

plt.figure(figsize=(12, 5))
plt.boxplot(df_counts, vert=False)
plt.title("Boxplot of Trace Clustering Only")
plt.xlabel("Document Frequency")
plt.grid(True)

max_val = df_counts.max()
tick_interval = 100_000
xticks = np.arange(0, max_val + tick_interval, tick_interval)
plt.xticks(xticks)

plt.show()

# %%
# number of ngrams remaining after reducing

# Based on IQR
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

idx_iqr = np.where((df_counts >= lower) & (df_counts <= upper))[0]
X_IQR = X[:, idx_iqr]

# Based on Boxplot
idx_500 = np.where(df_counts <= 0.15e6)[0]
X_box = X[:, idx_500]

print(f"Original number of ngrams: {X.shape[1]}")
print(f"Based on IQR: {X_IQR.shape[1]}")
print(f"Based on Box plot: {X_box.shape[1]}")
# Out:
# Original number of ngrams: 649
# Based on IQR: 536
# Based on Box plot: 635

# %%
#Frequency Feature Selection (IQR)

# 1. frequency of ngrams
df_counts = np.asarray(X.sum(axis=0)).flatten()

# 2. IQR 
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

# 3. Lower, Upper IQR
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# 4. Reduce ngrams
valid_idx = np.where((df_counts >= lower) & (df_counts <= upper))[0]

# 5. Filter
X_svd_box = X[:, valid_idx]

# %%
inertia_list = []

for k in range(1, 11):  
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_svd_box)  
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_list, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.title('Elbow Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.utils import resample

score = []
sample_size = 10000

for i in range(2, 11) :
    km = KMeans(n_clusters = i, random_state = 10)
    km.fit(X_svd_box)
    pred = km.predict(X_svd_box)

    if X_svd_box.shape[0] > sample_size:
        X_sample, labels_sample = resample(X_svd_box, pred, n_samples=sample_size, random_state=42)
    else:
        X_sample, labels_sample = X_svd, pred  # 샘플 수가 작으면 전체 사용

    sil_score = silhouette_score(X_sample, labels_sample, metric='cosine')
    score.append(sil_score)
    
    #score.append(silhouette_score(X_svd, pred))
    

plt.plot(range(2, 11), score, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %% [markdown]
# ## Model Training

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_svd_box)

trace_mapped_df['cluster'] = kmeans.labels_
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
trace_mapped_df.head()
# Out:
#    case:concept:name                                    activity_mapped  \
# 0           10000032  [b, c, d, d, d, d, d, d, d, d, d, d, a, f, f, ...
# 1           10000084  [b, c, a, d, d, d, d, d, d, a, e, a, f, f, b, ...
# 2           10000108  [b, c, a, f, b, c, a, e, e, f, b, c, d, a, e, ...
# 3           10000115               [b, c, a, a, f, f, f, b, a, c, f, f]
# 4           10000117  [b, c, a, d, a, f, b, c, a, f, f, f, b, c, a, ...
#
#                                         activity_str  cluster
# 0  b c d d d d d d d d d d a f f f f b c e e e a ...        1
# 1  b c a d d d d d d a e a f f b c a d d d d d d ...        1
# 2        b c a f b c a e e f b c d a e e a a e a a f        1
# 3                            b c a a f f f b a c f f        1
# 4              b c a d a f b c a f f f b c a a a f f        1

# %%
cluster_counts = trace_mapped_df['cluster'].value_counts().sort_index()

for cluster_id, count in cluster_counts.items():
    print(f"Traces in Cluster {cluster_id}: {count}")

# n = 2 (ngram:(3,4))
'''
Traces in Cluster 0: 201271
Traces in Cluster 1: 4195
'''

# n = 2 (ngram:(3,4))
'''
Traces in Cluster 0: 5653
Traces in Cluster 1: 199813
'''
# Out:
# Traces in Cluster 0: 5653
# Traces in Cluster 1: 199813
# '\nTraces in Cluster 0: 5653\nTraces in Cluster 1: 199813\n'

# %% [markdown]
# ## Process Discovery

# %%
cluster_logs = sg.split_event_log_by_cluster(trace_mapped_df, trace_ordered_df, case_id='case:concept:name')
cluster_models = sg.discover_process_models(cluster_logs)

# %%
results_df_tc = sg.evaluate_models_cluster(
    models_dict=cluster_models,
    trace_df=trace_mapped_df,
    full_event_df=trace_ordered_df,
    case_col='case:concept:name',
    time_col='time:timestamp'
)

# %%
results_df_tc
# Out:
#    Cluster  # Nodes  # Arcs       CNC    P/T-CD  Cyclomatic Number (CN)  \
# 0        1       43      56  1.302326  2.617391                      14
# 1        0       43      54  1.255814  2.546053                      12
#
#         ACD   Density  CFC  # Event Classes  # Variants  # Events
# 0  2.604651  0.031008    6                6      115856   5546667
# 1  2.511628  0.029900    4                6        5653   2022157

# %% [markdown]
# # Process Cube

# %%
import segmentation as sg
import pandas as pd
import numpy as np
from pm4py.objects.conversion.log import converter as log_converter
from pm4py.objects.log.util import dataframe_utils
from pm4py.algo.discovery.inductive import algorithm as inductive_miner
from pm4py.algo.conformance.tokenreplay import algorithm as token_replay
from pm4py.objects.conversion.process_tree import converter as tree_to_petri
from pm4py.visualization.petri_net import visualizer as pn_visualizer
import pm4py as pm
import os
import copy
from pm4py.algo.conformance.alignments.petri_net import algorithm as alignments
from pm4py.algo.evaluation.precision import algorithm as precision_evaluator
from pm4py.statistics.traces.generic.log import case_statistics

# %%
path = os.path.join(os.getcwd(),'data', 'mimicel.csv')
df = pd.read_csv(path)

# %%
df = df.rename(columns={
    'subject_id': 'case:concept:name',      
    'activity': 'concept:name',               
    'timestamps': 'time:timestamp'           
})

# %%
df = sg.define_race_hierarchy(df)
df = sg.define_time_hierarchy(df)
df = sg.define_activity_hierarchy(df)

# %%
pcs = sg.build_pcs_mimic()

# %%
pcv = sg.build_pcv(
    granularity={'time': 'month', 'race': 'race_regional', 'activity': 'activity_group'},
    filters={}
)

# %%
pcv = sg.rollup_pcv(pcv,pcs,'race')

# %%
pcv = sg.rollup_pcv(pcv,pcs,'activity')

# %%
mpcv = sg.materialize_process_cube_view(df, pcs, pcv)
print(f"Total number of cells: {len(mpcv)}")

for cell_key, sublog in mpcv.items():
    clean_key = tuple(int(k) if isinstance(k, np.integer) else k for k in cell_key)
    print(f"Cell {clean_key}: {len(sublog)} events")

total_events = sum(len(sublog) for sublog in mpcv.values())
print(f"Total number of events: {total_events}")
# Out:
# Total number of cells: 144
# Cell (1, 'ASIAN', 'Clinical'): 15489 events
# Cell (1, 'ASIAN', 'Operational'): 6388 events
# Cell (1, 'BLACK', 'Clinical'): 108028 events
# Cell (1, 'BLACK', 'Operational'): 33300 events
# Cell (1, 'HISPANIC/LATINO', 'Clinical'): 39058 events
# Cell (1, 'HISPANIC/LATINO', 'Operational'): 12554 events
# Cell (1, 'OTHER', 'Clinical'): 22774 events
# Cell (1, 'OTHER', 'Operational'): 8273 events
# Cell (1, 'UNKNOWN', 'Clinical'): 5780 events
# Cell (1, 'UNKNOWN', 'Operational'): 2556 events
# Cell (1, 'WHITE', 'Clinical'): 302793 events
# Cell (1, 'WHITE', 'Operational'): 85083 events
# Cell (2, 'ASIAN', 'Clinical'): 12491 events
# Cell (2, 'ASIAN', 'Operational'): 5224 events
# Cell (2, 'BLACK', 'Clinical'): 91786 events
# Cell (2, 'BLACK', 'Operational'): 29634 events
# Cell (2, 'HISPANIC/LATINO', 'Clinical'): 34514 events
# Cell (2, 'HISPANIC/LATINO', 'Operational'): 11001 events
# Cell (2, 'OTHER', 'Clinical'): 19901 events
# Cell (2, 'OTHER', 'Operational'): 7153 events
# Cell (2, 'UNKNOWN', 'Clinical'): 5159 events
# Cell (2, 'UNKNOWN', 'Operational'): 2275 events
# Cell (2, 'WHITE', 'Clinical'): 280483 events
# Cell (2, 'WHITE', 'Operational'): 78680 events
# Cell (3, 'ASIAN', 'Clinical'): 15560 events
# Cell (3, 'ASIAN', 'Operational'): 6101 events
# Cell (3, 'BLACK', 'Clinical'): 101538 events
# Cell (3, 'BLACK', 'Operational'): 32753 events
# Cell (3, 'HISPANIC/LATINO', 'Clinical'): 37962 events
# Cell (3, 'HISPANIC/LATINO', 'Operational'): 12526 events
# Cell (3, 'OTHER', 'Clinical'): 23332 events
# Cell (3, 'OTHER', 'Operational'): 8476 events
# Cell (3, 'UNKNOWN', 'Clinical'): 5790 events
# Cell (3, 'UNKNOWN', 'Operational'): 2729 events
# Cell (3, 'WHITE', 'Clinical'): 304111 events
# Cell (3, 'WHITE', 'Operational'): 85729 events
# Cell (4, 'ASIAN', 'Clinical'): 15267 events
# Cell (4, 'ASIAN', 'Operational'): 6127 events
# Cell (4, 'BLACK', 'Clinical'): 102357 events
# Cell (4, 'BLACK', 'Operational'): 32036 events
# Cell (4, 'HISPANIC/LATINO', 'Clinical'): 38229 events
# Cell (4, 'HISPANIC/LATINO', 'Operational'): 12329 events
# Cell (4, 'OTHER', 'Clinical'): 22646 events
# Cell (4, 'OTHER', 'Operational'): 8087 events
# Cell (4, 'UNKNOWN', 'Clinical'): 5993 events
# Cell (4, 'UNKNOWN', 'Operational'): 2466 events
# Cell (4, 'WHITE', 'Clinical'): 297635 events
# Cell (4, 'WHITE', 'Operational'): 83590 events
# Cell (5, 'ASIAN', 'Clinical'): 14409 events
# Cell (5, 'ASIAN', 'Operational'): 6328 events
# Cell (5, 'BLACK', 'Clinical'): 106150 events
# Cell (5, 'BLACK', 'Operational'): 32693 events
# Cell (5, 'HISPANIC/LATINO', 'Clinical'): 38726 events
# Cell (5, 'HISPANIC/LATINO', 'Operational'): 12677 events
# Cell (5, 'OTHER', 'Clinical'): 23079 events
# Cell (5, 'OTHER', 'Operational'): 8238 events
# Cell (5, 'UNKNOWN', 'Clinical'): 6128 events
# Cell (5, 'UNKNOWN', 'Operational'): 2599 events
# Cell (5, 'WHITE', 'Clinical'): 304340 events
# Cell (5, 'WHITE', 'Operational'): 85374 events
# Cell (6, 'ASIAN', 'Clinical'): 14978 events
# Cell (6, 'ASIAN', 'Operational'): 5968 events
# Cell (6, 'BLACK', 'Clinical'): 103769 events
# Cell (6, 'BLACK', 'Operational'): 32301 events
# Cell (6, 'HISPANIC/LATINO', 'Clinical'): 37124 events
# Cell (6, 'HISPANIC/LATINO', 'Operational'): 12110 events
# Cell (6, 'OTHER', 'Clinical'): 22117 events
# Cell (6, 'OTHER', 'Operational'): 8097 events
# Cell (6, 'UNKNOWN', 'Clinical'): 5502 events
# Cell (6, 'UNKNOWN', 'Operational'): 2497 events
# Cell (6, 'WHITE', 'Clinical'): 295838 events
# Cell (6, 'WHITE', 'Operational'): 83589 events
# Cell (7, 'ASIAN', 'Clinical'): 15447 events
# Cell (7, 'ASIAN', 'Operational'): 6135 events
# Cell (7, 'BLACK', 'Clinical'): 104357 events
# Cell (7, 'BLACK', 'Operational'): 32679 events
# Cell (7, 'HISPANIC/LATINO', 'Clinical'): 37743 events
# Cell (7, 'HISPANIC/LATINO', 'Operational'): 12253 events
# Cell (7, 'OTHER', 'Clinical'): 23433 events
# Cell (7, 'OTHER', 'Operational'): 8115 events
# Cell (7, 'UNKNOWN', 'Clinical'): 5664 events
# Cell (7, 'UNKNOWN', 'Operational'): 2704 events
# Cell (7, 'WHITE', 'Clinical'): 303603 events
# Cell (7, 'WHITE', 'Operational'): 85876 events
# Cell (8, 'ASIAN', 'Clinical'): 15574 events
# Cell (8, 'ASIAN', 'Operational'): 6343 events
# Cell (8, 'BLACK', 'Clinical'): 104046 events
# Cell (8, 'BLACK', 'Operational'): 32756 events
# Cell (8, 'HISPANIC/LATINO', 'Clinical'): 37434 events
# Cell (8, 'HISPANIC/LATINO', 'Operational'): 12473 events
# Cell (8, 'OTHER', 'Clinical'): 22116 events
# Cell (8, 'OTHER', 'Operational'): 8297 events
# Cell (8, 'UNKNOWN', 'Clinical'): 5293 events
# Cell (8, 'UNKNOWN', 'Operational'): 2594 events
# Cell (8, 'WHITE', 'Clinical'): 308430 events
# Cell (8, 'WHITE', 'Operational'): 86449 events
# Cell (9, 'ASIAN', 'Clinical'): 13732 events
# Cell (9, 'ASIAN', 'Operational'): 5837 events
# Cell (9, 'BLACK', 'Clinical'): 101978 events
# Cell (9, 'BLACK', 'Operational'): 32247 events
# Cell (9, 'HISPANIC/LATINO', 'Clinical'): 36858 events
# Cell (9, 'HISPANIC/LATINO', 'Operational'): 11932 events
# Cell (9, 'OTHER', 'Clinical'): 21716 events
# Cell (9, 'OTHER', 'Operational'): 7699 events
# Cell (9, 'UNKNOWN', 'Clinical'): 5775 events
# Cell (9, 'UNKNOWN', 'Operational'): 2641 events
# Cell (9, 'WHITE', 'Clinical'): 300415 events
# Cell (9, 'WHITE', 'Operational'): 83094 events
# Cell (10, 'ASIAN', 'Clinical'): 15765 events
# Cell (10, 'ASIAN', 'Operational'): 6405 events
# Cell (10, 'BLACK', 'Clinical'): 105329 events
# Cell (10, 'BLACK', 'Operational'): 33048 events
# Cell (10, 'HISPANIC/LATINO', 'Clinical'): 38076 events
# Cell (10, 'HISPANIC/LATINO', 'Operational'): 12145 events
# Cell (10, 'OTHER', 'Clinical'): 22558 events
# Cell (10, 'OTHER', 'Operational'): 8021 events
# Cell (10, 'UNKNOWN', 'Clinical'): 5914 events
# Cell (10, 'UNKNOWN', 'Operational'): 2720 events
# Cell (10, 'WHITE', 'Clinical'): 310026 events
# Cell (10, 'WHITE', 'Operational'): 86959 events
# Cell (11, 'ASIAN', 'Clinical'): 14942 events
# Cell (11, 'ASIAN', 'Operational'): 6252 events
# Cell (11, 'BLACK', 'Clinical'): 101042 events
# Cell (11, 'BLACK', 'Operational'): 32135 events
# Cell (11, 'HISPANIC/LATINO', 'Clinical'): 38410 events
# Cell (11, 'HISPANIC/LATINO', 'Operational'): 12118 events
# Cell (11, 'OTHER', 'Clinical'): 22279 events
# Cell (11, 'OTHER', 'Operational'): 8131 events
# Cell (11, 'UNKNOWN', 'Clinical'): 6308 events
# Cell (11, 'UNKNOWN', 'Operational'): 2678 events
# Cell (11, 'WHITE', 'Clinical'): 300240 events
# Cell (11, 'WHITE', 'Operational'): 83770 events
# Cell (12, 'ASIAN', 'Clinical'): 15190 events
# Cell (12, 'ASIAN', 'Operational'): 6447 events
# Cell (12, 'BLACK', 'Clinical'): 105010 events
# Cell (12, 'BLACK', 'Operational'): 33053 events
# Cell (12, 'HISPANIC/LATINO', 'Clinical'): 37431 events
# Cell (12, 'HISPANIC/LATINO', 'Operational'): 12348 events
# Cell (12, 'OTHER', 'Clinical'): 23157 events
# Cell (12, 'OTHER', 'Operational'): 8102 events
# Cell (12, 'UNKNOWN', 'Clinical'): 6102 events
# Cell (12, 'UNKNOWN', 'Operational'): 2743 events
# Cell (12, 'WHITE', 'Clinical'): 306462 events
# Cell (12, 'WHITE', 'Operational'): 85393 events
# Total number of events: 7568824

# %%
dimensions = pcv['visible_dimensions']
columns = [pcv['granularity'][dim] for dim in dimensions] + ['Event Count']

cell_data = []

for cell_key, sublog in mpcv.items():
    cell_data.append((*cell_key, len(sublog))) 

filtered_mpcv = pd.DataFrame(cell_data, columns=columns)

top2_per_month = (
    filtered_mpcv.sort_values([pcv['granularity']['time'], 'Event Count'], ascending=[True, False])
      .groupby(pcv['granularity']['time'])
      .head(2)
)

top2_per_race = (
    filtered_mpcv.sort_values([pcv['granularity']['race'], 'Event Count'], ascending=[True, False])
      .groupby(pcv['granularity']['race'])
      .head(2)
)

top2_per_activity = (
    filtered_mpcv
    .groupby(pcv['granularity']['activity'], group_keys=False)
    .apply(lambda df: df.sort_values('Event Count', ascending=False).head(2))
)

# %% [markdown]
# ### Top 2 cells with the highest number of events from different races

# %%
sorted_cells = filtered_mpcv.sort_values('Event Count', ascending=False)


cell_list = []
seen_races = set()


race_col = pcv['granularity']['race']
activity_col = pcv['granularity']['activity']
time_col = pcv['granularity']['time']

for _, row in sorted_cells.iterrows():
    race = row[race_col]
    if race not in seen_races:
        seen_races.add(race)
        cell_list.append((row[time_col], race, row[activity_col]))
    if len(cell_list) == 2:
        break

print(cell_list)
# Out:
# [(10, 'WHITE', 'Clinical'), (1, 'BLACK', 'Clinical')]

# %% [markdown]
# ### Process Discovery

# %%
models = sg.discover_models_for_cells(df, cell_list, dim1=pcv['granularity']['time'], dim2=pcv['granularity']['race'], dim3=pcv['granularity']['activity'])
# Out:
# Cell (10, 'WHITE', 'Clinical') Number of events: 310026
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# Cell (1, 'BLACK', 'Clinical') Number of events: 108028
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])

# %% [markdown]
# ### Evaluation

# %%
results_df_pc = sg.evaluate_models_pc(df, models, dim1=pcv['granularity']['time'], dim2=pcv['granularity']['race'], dim3=pcv['granularity']['activity'])

# %%
results_df_pc
# Out:
#                     Cell  # Nodes  # Arcs       CNC   P/T-CD  \
# 0  (10, WHITE, Clinical)       31      38  1.225806  2.47479
# 1   (1, BLACK, Clinical)       31      38  1.225806  2.47479
#
#    Cyclomatic Number (CN)       ACD  Density  CFC  # Event Classes  \
# 0                       8  2.451613  0.04086    3                3
# 1                       8  2.451613  0.04086    3                3
#
#    # Variants  # Events
# 0       10024    310026
# 1        3645    108028

# %% [markdown]
# # TC --> PC

# %%
all_results = []

for cluster_id, cluster_df in cluster_logs.items():
    cluster_df = sg.define_race_hierarchy(cluster_df)
    cluster_df = sg.define_time_hierarchy(cluster_df)
    cluster_df = sg.define_activity_hierarchy(cluster_df)

    pcs = sg.build_pcs_mimic()
    pcv = sg.build_pcv(
        granularity={'time': 'month', 'race': 'race_regional', 'activity': 'activity_group'},
        filters={}
    )
    pcv = sg.rollup_pcv(pcv,pcs,'race')
    
    mpcv = sg.materialize_process_cube_view(cluster_df, pcs, pcv)

    total_events = sum(len(sublog) for sublog in mpcv.values())
    print(f"Total number of events: {total_events}")

    dimensions = pcv['visible_dimensions']
    columns = [pcv['granularity'][dim] for dim in dimensions] + ['Event Count']
    
    cell_data = []
    for cell_key, sublog in mpcv.items():
        cell_data.append((*cell_key, len(sublog))) 
    
    filtered_mpcv = pd.DataFrame(cell_data, columns=columns)

    cell_list= [(10, 'WHITE', 'Clinical'), (1, 'BLACK', 'Clinical')]
    models_tc_pc = sg.discover_models_for_cells(cluster_df, cell_list)
    
    results_df_tc_pc = sg.evaluate_models_pc(cluster_df, models_tc_pc)
    results_df_tc_pc['cluster_id'] = cluster_id
    all_results.append(results_df_tc_pc)
    
results_df_tc_pc_all = pd.concat(all_results, ignore_index=True)

results_df_tc_pc_all
# Out:
# D:\Module12\practice\segmentation.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_specific'] = df.groupby('case:concept:name')['race'].transform(lambda x: x.ffill().bfill()).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_regional'] = df['race_specific'].map(race_group_map).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_continental'] = df['race_specific'].map(race_category_map).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_datetime(df[time])
# D:\Module12\practice\segmentation.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['timestamp'].dt.year
# D:\Module12\practice\segmentation.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['timestamp'].dt.month
# D:\Module12\practice\segmentation.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['timestamp'].dt.day
# D:\Module12\practice\segmentation.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity_group'] = df['concept:name'].map(activity_group_map).fillna('OTHER')
# D:\Module12\practice\segmentation.py:272: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity_category'] = df['activity_group'].map(activity_domain_map).fillna('Unclassified')
# Total number of events: 5546667
# Cell (10, 'WHITE', 'Clinical') Number of events: 232679
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# Cell (1, 'BLACK', 'Clinical') Number of events: 61540
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# D:\Module12\practice\segmentation.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_specific'] = df.groupby('case:concept:name')['race'].transform(lambda x: x.ffill().bfill()).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_regional'] = df['race_specific'].map(race_group_map).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['race_continental'] = df['race_specific'].map(race_category_map).fillna('UNKNOWN')
# D:\Module12\practice\segmentation.py:131: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp'] = pd.to_datetime(df[time])
# D:\Module12\practice\segmentation.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['timestamp'].dt.year
# D:\Module12\practice\segmentation.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'] = df['timestamp'].dt.month
# D:\Module12\practice\segmentation.py:134: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day'] = df['timestamp'].dt.day
# D:\Module12\practice\segmentation.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity_group'] = df['concept:name'].map(activity_group_map).fillna('OTHER')
# D:\Module12\practice\segmentation.py:272: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['activity_category'] = df['activity_group'].map(activity_domain_map).fillna('Unclassified')
# Total number of events: 2022157
# Cell (10, 'WHITE', 'Clinical') Number of events: 77342
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# Cell (1, 'BLACK', 'Clinical') Number of events: 46490
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
#                     Cell  # Nodes  # Arcs       CNC   P/T-CD  \
# 0  (10, WHITE, Clinical)       31      38  1.225806  2.47479
# 1   (1, BLACK, Clinical)       31      38  1.225806  2.47479
# 2  (10, WHITE, Clinical)       31      38  1.225806  2.47479
# 3   (1, BLACK, Clinical)       31      38  1.225806  2.47479
#
#    Cyclomatic Number (CN)       ACD  Density  CFC  # Event Classes  \
# 0                       8  2.451613  0.04086    3                3
# 1                       8  2.451613  0.04086    3                3
# 2                       8  2.451613  0.04086    3                3
# 3                       8  2.451613  0.04086    3                3
#
#    # Variants  # Events  cluster_id
# 0        8581    232679           1
# 1        2716     61540           1
# 2        1700     77342           0
# 3        1075     46490           0

# %% [markdown]
# # PC --> TC

# %%
path = os.path.join(os.getcwd(),'data', 'mimicel.csv')
df_pc_tc = pd.read_csv(path)
df_pc_tc = df_pc_tc.rename(columns={
    'subject_id': 'case:concept:name',      
    'activity': 'concept:name',               
    'timestamps': 'time:timestamp'           
})
df_pc_tc = sg.define_race_hierarchy(df_pc_tc)
df_pc_tc = sg.define_time_hierarchy(df_pc_tc)
df_pc_tc = sg.define_activity_hierarchy(df_pc_tc)

# %%
pcs = sg.build_pcs_mimic()

pcv = sg.build_pcv(
    granularity={'time': 'month', 'race': 'race_continental', 'activity': 'activity_category'},
    filters={}
)

# %%
mpcv = sg.materialize_process_cube_view(df_pc_tc, pcs, pcv)

target_cell1 = (10, 'WHITE', 'Clinical')
target_cell2 = (1, 'BLACK', 'Clinical')

sublog1 = mpcv[target_cell1]
sublog2 = mpcv[target_cell2]

# %% [markdown]
# ## Trace Clustering Sublog1

# %%
activities = sublog1['concept:name'].unique() # extract activities

# mapping activities
mapping = {act: chr(97 + i) for i, act in enumerate(activities)} 
sublog1['activity_mapped'] = sublog1['concept:name'].map(mapping)

sublog1_ordered_df = sublog1.sort_values(by=['case:concept:name', 'time:timestamp']) # order by case ids
sublog1_mapped_df = sublog1_ordered_df.groupby('case:concept:name')["activity_mapped"].apply(list).reset_index() # group by case ids

# %%
sublog1_mapped_df['activity_str'] = sublog1_mapped_df['activity_mapped'].apply(lambda x: ' '.join(x))

vectorizer = CountVectorizer(
    ngram_range=(3, 4),
    stop_words=None,                     
    token_pattern=r'(?u)\b\w+\b'         
)

X = vectorizer.fit_transform(sublog1_mapped_df['activity_str'])

# %%
df_counts = np.asarray(X.sum(axis=0)).flatten()

plt.figure(figsize=(12, 5))
plt.boxplot(df_counts, vert=False)
plt.title("Boxplot of PC->TC")
plt.xlabel("Document Frequency")
plt.grid(True)
plt.show()

# %%
# number of ngrams remaining after reducing

# Based on IQR
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

idx_1500 = np.where((df_counts >= lower) & (df_counts <= upper))[0]
X_IQR = X[:, idx_1500]

# Based on Boxplot
idx_500 = np.where(df_counts <= 20000)[0]
X_box = X[:, idx_500]

print(f"Original number of ngrams: {X.shape[1]}")
print(f"Based on IQR: {X_IQR.shape[1]}")
print(f"Based on Box plot: {X_box.shape[1]}")
# Out:
# Original number of ngrams: 108
# Based on IQR: 101
# Based on Box plot: 105

# %%
#Frequency Feature Selection (IQR)

# 1. frequency of ngrams
df_counts = np.asarray(X.sum(axis=0)).flatten()

# 2. IQR 
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

# 3. Lower, Upper IQR
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# 4. Reduce ngrams
valid_idx = np.where((df_counts >= lower) & (df_counts <= upper))[0]

# 5. Filter
X_filtered_iqr = X[:, valid_idx]

# %%
svd = TruncatedSVD(n_components=50) # clusters get worse as n_components increases
X_svd = svd.fit_transform(X_filtered_iqr)

print(svd.explained_variance_ratio_.sum())
# Out:
# 0.994147124118226

# %%
inertia_list = []

for k in range(1, 11):  
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_svd)  
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_list, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.title('Elbow Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
score = []

for i in range(2, 11) :
    km = KMeans(n_clusters = i, random_state = 10)
    km.fit(X_svd)
    pred = km.predict(X_svd)
    score.append(silhouette_score(X_svd, pred))

plt.plot(range(2, 11), score, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_svd)

sublog1_mapped_df['cluster'] = kmeans.labels_
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_counts = sublog1_mapped_df['cluster'].value_counts().sort_index()

for cluster_id, count in cluster_counts.items():
    print(f"Traces in Cluster {cluster_id}: {count}")
# Out:
# Traces in Cluster 0: 1864
# Traces in Cluster 1: 15475

# %%
cluster_logs = sg.split_event_log_by_cluster(sublog1_mapped_df, sublog1_ordered_df)
cluster_models = sg.discover_process_models(cluster_logs)
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])

# %%
results_df_pc_tc1 = sg.evaluate_models_cluster(
    models_dict=cluster_models,
    trace_df=sublog1_mapped_df,
    full_event_df=sublog1_ordered_df
)

# %%
results_df_pc_tc1
# Out:
#    Cluster  # Nodes  # Arcs       CNC   P/T-CD  Cyclomatic Number (CN)  \
# 0        1       31      38  1.225806  2.47479                       8
# 1        0       26      32  1.230769  2.47619                       7
#
#         ACD   Density  CFC  # Event Classes  # Variants  # Events
# 0  2.451613  0.040860    3                3        8159    210531
# 1  2.461538  0.049231    3                3        1864     99495

# %% [markdown]
# ## Trace Clustering Sublog2

# %%
activities = sublog2['concept:name'].unique() # extract activities

# mapping activities
mapping = {act: chr(97 + i) for i, act in enumerate(activities)} 
sublog2['activity_mapped'] = sublog2['concept:name'].map(mapping)

sublog2_ordered_df = sublog2.sort_values(by=['case:concept:name', 'time:timestamp']) # order by case ids
sublog2_mapped_df = sublog2_ordered_df.groupby('case:concept:name')["activity_mapped"].apply(list).reset_index() # group by case ids

# %%
sublog2_mapped_df['activity_str'] = sublog2_mapped_df['activity_mapped'].apply(lambda x: ' '.join(x))

vectorizer = CountVectorizer(
    ngram_range=(3, 4),
    stop_words=None,                     
    token_pattern=r'(?u)\b\w+\b'         
)

X = vectorizer.fit_transform(sublog2_mapped_df['activity_str'])

# %%
df_counts = np.asarray(X.sum(axis=0)).flatten()

plt.figure(figsize=(12, 5))
plt.boxplot(df_counts, vert=False)
plt.title("Boxplot of PC->TC")
plt.xlabel("Document Frequency")
plt.grid(True)
plt.show()

# %%
# number of ngrams remaining after reducing

# Based on IQR
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

idx_1500 = np.where((df_counts >= lower) & (df_counts <= upper))[0]
X_IQR = X[:, idx_1500]

# Based on Boxplot
idx_500 = np.where(df_counts <= 20000)[0]
X_box = X[:, idx_500]

print(f"Original number of ngrams: {X.shape[1]}")
print(f"Based on IQR: {X_IQR.shape[1]}")
print(f"Based on Box plot: {X_box.shape[1]}")
# Out:
# Original number of ngrams: 107
# Based on IQR: 100
# Based on Box plot: 105

# %%
#Frequency Feature Selection (IQR)

# 1. frequency of ngrams
df_counts = np.asarray(X.sum(axis=0)).flatten()

# 2. IQR 
Q1 = np.percentile(df_counts, 25)
Q3 = np.percentile(df_counts, 75)
IQR = Q3 - Q1

# 3. Lower, Upper IQR
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# 4. Reduce ngrams
valid_idx = np.where((df_counts >= lower) & (df_counts <= upper))[0]

# 5. Filter
X_filtered_iqr = X[:, valid_idx]

# %%
svd = TruncatedSVD(n_components=50) # clusters worse as n_components increases
X_svd = svd.fit_transform(X_filtered_iqr)

print(svd.explained_variance_ratio_.sum())
# Out:
# 0.9947979418917493

# %%
inertia_list = []

for k in range(1, 11):  
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_svd)  
    inertia_list.append(kmeans.inertia_)
    
plt.plot(range(1, 11), inertia_list, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia (WCSS)')
plt.title('Elbow Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
score = []

for i in range(2, 11) :
    km = KMeans(n_clusters = i, random_state = 10)
    km.fit(X_svd)
    pred = km.predict(X_svd)
    score.append(silhouette_score(X_svd, pred))

plt.plot(range(2, 11), score, marker='o')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal k')
plt.show()
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_svd)

sublog2_mapped_df['cluster'] = kmeans.labels_
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_counts = sublog2_mapped_df['cluster'].value_counts().sort_index()

for cluster_id, count in cluster_counts.items():
    print(f"Traces in Cluster {cluster_id}: {count}")
# Out:
# Traces in Cluster 0: 5167
# Traces in Cluster 1: 581

# %%
cluster_logs = sg.split_event_log_by_cluster(sublog2_mapped_df, sublog2_ordered_df)
cluster_models = sg.discover_process_models(cluster_logs)
# Out:
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pandas_utils.dataframe_column_string_to_datetime(df[col], format=timest_format, utc=True)
# c:\users\park\appdata\local\programs\python\python38\lib\site-packages\pm4py\objects\log\util\dataframe_utils.py:203: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = strpfromiso.fix_dataframe_column(df[col])

# %%
results_df_pc_tc2 = sg.evaluate_models_cluster(
    models_dict=cluster_models,
    trace_df=sublog2_mapped_df,
    full_event_df=sublog2_ordered_df
)

# %%
results_df_pc_tc2
# Out:
#    Cluster  # Nodes  # Arcs       CNC   P/T-CD  Cyclomatic Number (CN)  \
# 0        0       31      38  1.225806  2.47479                       8
# 1        1       26      32  1.230769  2.47619                       7
#
#         ACD   Density  CFC  # Event Classes  # Variants  # Events
# 0  2.451613  0.040860    3                3        3066     69158
# 1  2.461538  0.049231    3                3         581     38870
